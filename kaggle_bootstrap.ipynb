# %% [markdown]
# # iSE Data-Lake QA — Kaggle bootstrap
#
# Settings: **GPU T4 x2**, **Internet On**. Add Inputs: the data-lake dataset + the questions xlsx.

# %% [markdown]
# ## 1. Install + clone the repo

# %%
# !pip -q install sentence-transformers qdrant-client fastembed faster-whisper
# !apt-get -qq install -y libreoffice >/dev/null 2>&1 && echo libreoffice ready
# !rm -rf /kaggle/working/dlqa-repo && git clone -q https://github.com/MothMalone/dlqa.git /kaggle/working/dlqa-repo
# !pip -q install -e /kaggle/working/dlqa-repo

# %% [markdown]
# ## 2. Set key + run everything -> submission.csv

# %%
import os
os.environ["OPENROUTER_API_KEY"] = "sk-or-REPLACE_ME"   # <-- paste your key
from dlqa.kaggle import run_all
run_all()
